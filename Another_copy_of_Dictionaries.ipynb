# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekganganalli/class.ipynb_int-float-str_abhishekganganalli/blob/main/Another_copy_of_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={"jan":100,"feb":200}
type(d)
# Out:
# dict

# %%
d={"jan":{"day1":200},"feb":200}
d['jan']
# Out:
# {'day1': 200}

# %%
key datatypes : int,float,string,tuple
values : any datatypes

# %%
store_metrics={    "month":["jan","feb","march"],
    "customers":[100,2200,1000],
    "sales":[100,1000,2000],
    "trasactions":[100,12100,1000]
 }
store_metrics
# Out:
# {'month': ['jan', 'feb', 'march'],
#  'customers': [100, 2200, 1000],
#  'sales': [100, 1000, 2000],
#  'trasactions': [100, 12100, 1000]}

# %%
json

# %%
product = {
    "product_id": 101,
    "product_name": "Laptop",
    "brand": "Dell",
    "category": "Electronics",
    "price": 65000,
    "stock": 45,
    "discount": 0.10,
    "rating": 4.7
}
product['discount']
# Out:
# 0.1

# %%
store['sales']['today_sales']
# Out:
# 250000

# %%
print(store["store_info"]["store_name"])
print(store["store_info"]["city"])
print(store["sales"]["today_sales"])
print(store["sales"]["profit"])
# Out:
# Bangalore Mall
# Bangalore
# 250000
# 42000

# %%
store = {
    "store_info": {
        "store_id": 1,
        "store_name": "Bangalore Mall",
        "city": "Bangalore",
        "manager": "Rahul"
    },
    "sales": {
        "today_sales": 250000,
        "customers": 350,
        "transactions": 180,
        "profit": 42000
    }
}

# %%
retail['store']['details']['store_id']
# Out:
# 101

# %%
print(retail["store"]["details"]["store_name"])
print(retail["store"]["manager"]["name"])
print(retail["inventory"]["electronics"]["Laptop"])
print(retail["inventory"]["fashion"]["Shoes"])

# %%
retail = {
    "store": {
        "details": {
            "store_id": 101,
            "store_name": "Edukron Retail",
            "city": "Bangalore",
            "state": "Karnataka"
        },
        "manager": {
            "employee_id": 501,
            "name": "Anil Kumar",
            "experience": 8,
            "email": "anil@retail.com"
        }
    },

    "inventory": {
        "electronics": {
            "Laptop": 40,
            "Mobile": 120,
            "Tablet": 35
        },
        "fashion": {
            "Shirts": 200,
            "Jeans": 150,
            "Shoes": 90
        }
    }
}

# %%
print(retail["store"]["details"]["store_id"])

print(retail["store"]["details"]["store_name"])

print(retail["store"]["details"]["city"])

print(retail["store"]["manager"]["employee_id"])

print(retail["store"]["manager"]["name"])

print(retail["store"]["manager"]["email"])

print(retail["inventory"]["electronics"]["Laptop"])

print(retail["inventory"]["electronics"]["Mobile"])

print(retail["inventory"]["fashion"]["Shirts"])

print(retail["inventory"]["fashion"]["Shoes"])

# %%
d={"jan":100,"feb":[200,300]}
d
# Out:
# {'jan': 100, 'feb': [200, 300]}

# %%
d.get("jan",0)  ### if it is present you will get the output else you
### can provide a default value
# Out:
# 400

# %%
d['jan1']  ### it expect key to be present in dictionary
# Out:
# 100

# %%
d.items()
# Out:
# dict_items([('jan', 100), ('feb', [200, 300])])

# %%
d.values()
# Out:
# dict_values([100, [200, 300]])

# %%
d.keys()
# Out:
# dict_keys(['jan', 'feb'])

# %%
d
# Out:
# {'jan': 100, 'feb': [200, 300]}

# %%
d.pop("jan")
# Out:
# 100

# %%
d
# Out:
# {'feb': [200, 300]}

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1532/3161387801.py in <cell line: 0>()
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
d={"jan":100,"feb":200}
x=d
x["jan"]=400
print(x,d)
# Out:
# {'jan': 400, 'feb': 200} {'jan': 400, 'feb': 200}

# %%
d={"jan":100,"feb":200}
x=d.copy()
x["jan"]=400
print(x,d)
# Out:
# {'jan': 400, 'feb': 200} {'jan': 100, 'feb': 200}

# %%
months=['jan','feb',(1,2,3)]
x=dict.fromkeys(months,[1,2,3])
print(x)
# Out:
# {'jan': [1, 2, 3], 'feb': [1, 2, 3], (1, 2, 3): [1, 2, 3]}

# %%
d={"jan1":100,"feb":200}
d.setdefault("jan",500)

### ifthe key exist it will return the values
### otherwise it will insert the keys with a default value
# Out:
# 500

# %%
d={"jan":100,"feb":400}
min(d)
# Out:
# 'feb'

# %%
min(d),len(d),max(d)
# Out:
# ('feb', 2, 'jan')

# %%
d.keys(),max(d)
# Out:
# (dict_keys(['jan', 'feb']), 'jan')

# %%
x=[1,2,3,4]
y=(1,2,3,4)
min(x),min(y)
# Out:
# (1, 1)

# %%
x=[1,2,3]
x.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1532/1491867339.py in <cell line: 0>()
#       1 x=[1,2,3]
# ----> 2 x.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
d={"jan":{"day1":200},"feb":200}
d['jan']
# Out:
# {'day1': 200}

# %%
d={"jan":{"day1":200},"feb":[200]}
d['feb']
# Out:
# [200]

# %%
store_metrics={    "month":["jan","feb","march"],
    "customers":[100,2200,1000],
    "sales":[100,1000,2000],
    "trasactions":[100,12100,1000]
 }
(store_metrics["sales"],store_metrics["trasactions"])
# Out:
# ([100, 1000, 2000], [100, 12100, 1000])

# %%
product = {
    "product_id": 101,
    "product_name": "Laptop",
    "brand": "Dell",
    "category": "Electronics",
    "price": 65000,
    "stock": 45,
    "discount": 0.10,
    "rating": 4.7
}
product["category"],product['discount']
# Out:
# ('Electronics', 0.1)

# %%
store = {
    "store_info": {
        "store_id": 1,
        "store_name": "Bangalore Mall",
        "city": "Bangalore",
        "manager": "Rahul"
    },
    "sales": {
        "today_sales": 250000,
        "customers": 350,
        "transactions": 180,
        "profit": 42000
    }
}
print(store["store_info"]['store_id'])
print(store["sales"]["customers"])
print(store["sales"]["profit"])
print(store["sales"]["transactions"])
print(store["store_info"]["store_name"])
print(store["store_info"]["manager"])
# Out:
# 1
# 350
# 42000
# 180
# Bangalore Mall
# Rahul

# %%
retail = {
    "store": {
        "details": {
            "store_id": 101,
            "store_name": "Edukron Retail",
            "city": "Bangalore",
            "state": "Karnataka"
        },
        "manager": {
            "employee_id": 501,
            "name": "Anil Kumar",
            "experience": 8,
            "email": "anil@retail.com"
        }
    },

    "inventory": {
        "electronics": {
            "Laptop": 40,
            "Mobile": 120,
            "Tablet": 35
        },
        "fashion": {
            "Shirts": 200,
            "Jeans": 150,
            "Shoes": 90
        }
    }
}
print(retail["store"]["details"]["store_name"])
print(retail["store"]["details"]["state"])
print(retail["store"]['manager']["employee_id"])
print(retail['inventory']['electronics']['Mobile'])
print(retail["inventory"]['fashion']['Jeans'])
print(retail['store']["manager"]["email"])
# Out:
# Edukron Retail
# Karnataka
# 501
# 120
# 150
# anil@retail.com

# %%
d={'jan':200,"feb":100}
x=d.copy()
x['jan']=150
d,x
# Out:
# ({'jan': 200, 'feb': 100}, {'jan': 150, 'feb': 100})

# %%
d={"jan":500,"feb":800}
d=x
x['feb']=200
x,d
# Out:
# ({'jan': 400, 'feb': 200}, {'jan': 400, 'feb': 200})

# %%
d={"jan":100,"feb":[200,300]}
d.items()
# Out:
# dict_items([('jan', 100), ('feb', [200, 300])])

# %%
d={"kiran":100,"abhi":200}
d.items()
d.values()
d.pop("abhi")
# Out:
# 200

# %%
d={"kiran":100,"abhi":200}
d
# Out:
# {'kiran': 100, 'abhi': 200}

# %%
d.clear()

# %%
d
# Out:
# {}

# %%
del d
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1068/3760071723.py in <cell line: 0>()
# ----> 1 del d
#       2 d
#
# NameError: name 'd' is not defined

# %%
name=["abhi",'kartik','kiran']
age=dict.fromkeys(name,['a'])
age
# Out:
# {'abhi': ['a'], 'kartik': ['a'], 'kiran': ['a']}

# %%
d={'jan':12,"feb":23}
d.setdefault('jan2',1)
# Out:
# 1
