# %% [markdown]
# # Banking Assignment — Exception Handling (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice try/except, custom exceptions, chaining, cleanup, resilient batch processing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Parse a deposit amount for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def parse_deposit(amt,ref='acc-101'):
    try:
        amount=float(amt)
    except(ValueError,TypeError):
        print(f'{ref} Not Valid number')
        

    if amount <=0:
        print(f'{ref} amount must be greater than 0')
    else:
        print(f'{ref} payment Success={amount}')
parse_deposit('2500','acc-1001')
parse_deposit('0','acc-1001')
# Out:
# acc-1001 payment Success=2500.0
# acc-1001 amount must be greater than 0

# %% [markdown]
# ### Q2. Handle a missing account key for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your soludion here
account={'acc-1002':3200}
def check_account(acc_id):
    try:
        return account[acc_id]
    except KeyError:
        print(f'{acc_id} not found')

print(check_account('acc-1002'),'account_balance')
print(check_account('acc-3837'))
# Out:
# 3200 account_balance
# acc-3837 not found
# None

# %% [markdown]
# ### Q3. Prevent division by zero in average balance for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def avg_balance(balance,ref='acc-1003'):
    try:
        return sum(balance)/len(balance)
    except ZeroDivisionError:
        print(f'{ref} no data to calculae average')

print(avg_balance([1000,2000,3000],'acc-1003'))
print(avg_balance([],'acc-1003'))
print(avg_balance([12322,322],'acc-1003'))
# Out:
# 2000.0
# acc-1003 no data to calculae average
# None
# 6322.0

# %% [markdown]
# ### Q4. Open a transaction file safely for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def txn_file(file_name,ref='acc-1004'):
    try:
        file=open(file_name,'r')
        return f'{ref} file opened successfully'
    except FileNotFoundError:
        return f'{ref} file not found'
    
print(txn_file('acc-1004'))
print(txn_file('acc-1004.txt'))
# Out:
# acc-1004 file not found
# acc-1004 file not found

# %% [markdown]
# ### Q5. Reject a negative withdrawal for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def withdrawl_amount(amount,ref='acc-1005'):
    try:
        amount=float(amount)
    except(ValueError,TypeError):
        print(f'{ref} not a valid number')
    
    if amount <=0:
        print(f'{ref} withdrawal amount must not be negative')
    else:
        print(f'{ref} withdrawl amount success={amount}')
print(withdrawl_amount('2500'))
print(withdrawl_amount('-324'))
# Out:
# acc-1005 withdrawl amount success=2500.0
# None
# acc-1005 withdrawal amount must not be negative
# None

# %% [markdown]
# ### Q6. Catch invalid tenure input for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def tenure_check(tenure,ref='acc-1006'):
    try:
        tenure=int(tenure)
        if tenure <=0:
            return f'{ref} invalid tenure must be positive'
        
        return f'{ref} tenure success={tenure} years'
    except ValueError:
        return f'{ref} invalid tenure not a number'
print(tenure_check(-5))
print(tenure_check(2))
print(tenure_check('dw'))
# Out:
# acc-1006 invalid tenure must be positive
# acc-1006 tenure success=2 years
# acc-1006 invalid tenure not a number

# %% [markdown]
# ### Q7. Use else after pin-format validation for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def pin_check(pin,ref='acc-1007'):
    try:
        pin_int=int(pin)
    except ValueError:
        return f'{ref} pin invalid-not numeric'
    else:
        if len(str(pin))==4:
            return f'{ref} pin is valid'
        else:
            return f'{ref} pin is invalid'
print(pin_check('qsd'))
print(pin_check(1222))
# Out:
# acc-1007 pin invalid-not numeric
# acc-1007 pin is valid

# %% [markdown]
# ### Q8. Use finally to close a session for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def close_session(balance,ref='acc-1008'):
    session_open=True
    try:
        bal=int(balance)
        return f'{ref} session processed'
    except ValueError:
        return f'{ref} invalid balance input'

    finally:
        session_open=False
        print(f'{ref} session closed')
print(close_session(2342))
print(close_session('qdq'))
# Out:
# acc-1008 session closed
# acc-1008 session processed
# acc-1008 session closed
# acc-1008 invalid balance input

# %% [markdown]
# ### Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def multi_convert(a,b,ref='acc-1009'):
    try:
        x=int(a)
        y=int(b)
        return f'{ref} conversion success {x+y}'
    except (ValueError,TypeError):
        return f'{ref} numeric conversion failed'

print(multi_convert(143,24))
print(multi_convert('ads',34))
# Out:
# acc-1009 conversion success 167
# acc-1009 numeric conversion failed

# %% [markdown]
# ### Q10. Raise a clear valueerror for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def validate_bal(bal,ref='1010'):
    try:
        balance=int(bal)
        if balance <0:
            raise ValueError(f'{ref} negative balance not allowed')
        return f'{ref} valid balance{balance}'
    except ValueError as a:
        return f'{ref} error:{a}'
print(validate_bal(13))
print(validate_bal('afdsa'))
# Out:
# 1010 valid balance13
# 1010 error:invalid literal for int() with base 10: 'afdsa'

# %% [markdown]
# ### Q11. Parse a deposit amount for banking case 2; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def praise_dep(amount,ref='acc-1011'):
    try:
        amt=int(amount)
    except (TypeError,ValueError):
        return f'{ref} not numeric'

    if amt<0:
        return f'{ref} amount must not be negative'
    else:
        return f'{ref} successfully deposited{amt}'

print(praise_dep ('300'))
print(praise_dep('asd'))
# Out:
# acc-1011 successfully deposited300
# acc-1011 not numeric

# %% [markdown]
# ### Q12. Handle a missing account key for banking case 2; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account_2={'acc-1012':2000}
def account_check(acc_id):
    try:
        return account_2[acc_id]
    except KeyError:
        print(f'{acc_id} not found' )
print(account_check('acc-1012') ,'account_balance')
print(account_check('acc-1014'))
# Out:
# 2000 account_balance
# acc-1014 not found
# None

# %% [markdown]
# ### Q13. Prevent division by zero in average balance for banking case 2; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def avg_balance(balance,ref='acc-1013'):
    try:
        return sum(balance)/len(balance)
    except ZeroDivisionError:
        return f'{ref} no data to calculate balance'
print(avg_balance([234,244]))
print(avg_balance([1000,3000],'acc-1012'))
# Out:
# 239.0
# 2000.0

# %% [markdown]
# ### Q14. Open a transaction file safely for banking case 2; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def txn_file(filename,ref='acc-1014'):
    try:
        file=open(filename,'r')
        return f'{ref} file opened successfully'
    except FileNotFoundError:
        return f'{ref} file not found'
    
    
print(txn_file('acc-1014'))
print(txn_file('acc-1014.txt'))
# Out:
# acc-1014 file not found
# acc-1014 file not found

# %% [markdown]
# ### Q15. Reject a negative withdrawal for banking case 2; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def negative_withdrawl(amount,ref='acc-1015'):
    try:
        amt=int(amount)
    except (TypeError,ValueError):
        return f'{ref} not entered numeric'
    if amt <= 0:
        return f'{ref} withdrawl must not be negative'
    else:
         return f'{ref} successfully withdraw{amt}'

print(negative_withdrawl('200'))
# Out:
# acc-1015 successfully withdraw200

# %% [markdown]
# ### Q16. Catch invalid tenure input for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def check_tenure(input_tenure,ref='1016'):
    try:
        tenure=int(input_tenure)
        if tenure <=0:
            return f'{ref} tenure not valid'
        return f'{ref} valid tenure success={tenure}'
    except ValueError:
        return f'{ref} not a numeric '
print(check_tenure(3))
print(check_tenure(-3))
print(check_tenure('ad'))
# Out:
# 1016 valid tenure success=3
# 1016 tenure not valid
# 1016 not a numeric

# %% [markdown]
# ### Q17. Use else after pin-format validation for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def pin_check(pin,ref='acc-1017'):
    try:
        pin_number=int(pin)
        if len(str(pin))==4:
            return f'{ref}  pin is valid'
        else:
            return f'{ref} pin must be 4 digit'

    except ValueError:
        return f'{ref} not numeric '
print(pin_check('1233'))
# Out:
# acc-1017  pin is valid

# %% [markdown]
# ### Q18. Use finally to close a session for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def close_session(balance,ref='acc-1018'):
    open_session=True
    try:
        bal=int(balance)
        return f'{ref} balance processed {bal}'
    except ValueError:
        return f'{ref} invalid balance input'
    finally:
        session_close=False
        print(f'{ref} session closed')

print(close_session(5000))
print(close_session('abc'))
# Out:
# acc-1018 session closed
# acc-1018 balance processed 5000
# acc-1018 session closed
# acc-1018 invalid balance input

# %% [markdown]
# ### Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def multi_convert(a,b,ref="acc-1019"):
    try:
        x=int(a)
        y=int(b)
        return f'{ref} conversion success amount balance is{x+y}'
    except (ValueError,TypeError) as e:
        return f'{ref} invalid conversion'
print(f'{multi_convert(23,23)}')
# Out:
# acc-1019 conversion success amount balance is46

# %% [markdown]
# ### Q20. Raise a clear valueerror for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def validate_bal(balance,ref='acc-1020'):
    try:
        bal=int(balance)
        if bal<=0:
            raise ValueError(f'{ref} balance must not be negative')
        return f'{ref} balance {bal}'
    except ValueError as a:
        return f'{ref} error:{a}'
print(validate_bal(200))
print(validate_bal(-23))
# Out:
# acc-1020 balance 200
# acc-1020 error:acc-1020 balance must not be negative

# %% [markdown]
# ### Q21. Parse a deposit amount for banking case 3; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def prase_deposit(amount,ref='acc-10021'):
    try:
        amt=int(amount)
    except (TypeError,ValueError):
        return f'{ref} not a numeric'
    if amt >0:
        return f'{amt} is deposited successfully in {ref}'
    else:
        return f'{ref} deposit amount should be greater than 0'
print(prase_deposit(200))
print(prase_deposit(-233))
# Out:
# 200 is deposited successfully in acc-10021
# acc-10021 deposit amount should be greater than 0

# %% [markdown]
# ### Q22. Handle a missing account key for banking case 3; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account_3={'acc-1022':2000}
def missing_account(acc_id):
    try:
        return account_3[acc_id]
    except KeyError:
        return f'{acc_id} not found'
print(missing_account('acc-1022'), 'balance')
print(missing_account('acc-121'))
# Out:
# 2000 balance
# acc-121 not found

# %% [markdown]
# ### Q23. Prevent division by zero in average balance for banking case 3; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def avg_balance(balance,ref='acc-1023'):
    try:
        return sum(balance)/len(balance)
    except ZeroDivisionError:
        return f'{ref} no data to calaculate average'
print(avg_balance([200,300]),'Average Balance of account')
# Out:
# 250.0 Average Balance of account

# %% [markdown]
# ### Q24. Open a transaction file safely for banking case 3; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def txn_file(file_name,ref='acc-1024'):
    try:
        file=open(file_name,'r')
        return f'{ref} file opened succeessfully'
    except FileNotFoundError:
        return f'{ref} file not found'
print(txn_file('acc-1024'))
# Out:
# acc-1024 file not found

# %% [markdown]
# ### Q25. Reject a negative withdrawal for banking case 3; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def negative_withdrawl_atm(amount,ref='acc-1025'):
    try:
        amt=int(amount)
    except(TypeError,ValueError):
        return f'{ref} not a numeric'
    if amt <=0:
        return f'{ref} withdrael amount must not be negative'
    else:
        return f'{ref} withdrawl amount success={amt}'
print(negative_withdrawl_atm('-300'))
print(negative_withdrawl_atm('a'))
# Out:
# acc-1025 withdrael amount must not be negative
# acc-1025 not a numeric

# %% [markdown]
# ### Q26. Catch invalid tenure input for banking case 3; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def tenure_check(tenure,ref='acc=1026'):
    try:
        validate=float(tenure)
    except(ValueError,TypeError):
        return f'{ref} not a numeric'
    if validate <=0:
        return f'{ref} tenure must be positive'
    else:
        return f'{ref} tenure success={tenure} years'
print(tenure_check(-2))
# Out:
# acc=1026 tenure must be positive

# %% [markdown]
# ### Q27. Use else after pin-format validation for banking case 3; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def pin_check(pin,ref='acc-1027'):
    try:
        pin=int(pin)
    except(ValueError,TypeError):
        return f'{ref} pin not a numeric'
    if len(str(pin))==4:
        return f'{ref} pin is valid'
    else:
        return f'{ref} pin is invalid'
print(pin_check('1234'))
print(pin_check('abc'))
# Out:
# acc-1027 pin is valid
# acc-1027 pin not a numeric

# %% [markdown]
# ### Q28. Use finally to close a session for banking case 3; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def close_session(balance,ref='acc-1028'):
    session_open=True
    try:
        bal=int(balance)
        return f'{ref} session processed'
    except ValueError:
        return f'{ref} invalid balance input'
    finally:
        session_open=False
print(close_session(2344))
# Out:
# acc-1028 session processed

# %% [markdown]
# ### Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def multi_convert(x,y,ref='acc-1029'):
    try:
        first_trans=int(x)
        second_trans=int(y)
        return f'{ref} conversion success {first_trans+second_trans}'
    except(ValueError,TypeError):
        return f'{ref} conversion failed'
print(multi_convert(23,34))
# Out:
# acc-1029 conversion success 57

# %% [markdown]
# ### Q30. Raise a clear valueerror for banking case 3; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def valueerror_check(balance,ref='acc-1020'):
    try:
        bal=int(balance)
        if bal<=0:
            raise ValueError(f'{ref} balance must not be negative')
        return f'{ref} balance {bal}'
    except ValueError as a:
        return f'{ref} error:{a}'
print(valueerror_check('a'))
print(valueerror_check(-23))
# Out:
# acc-1020 error:invalid literal for int() with base 10: 'a'
# acc-1020 error:acc-1020 balance must not be negative

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Create insufficientfundserror for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class insufficient_funds(Exception):pass
    
def withdrawl(amount,balance,ref='acc-1031'):
    bal=float(balance)
    amt=float(amount)
    if amt> bal:
        raise insufficient_funds(f'{ref} withdrawl amount {amt} is greater than balance {bal}')
    else:
        return f'{ref} withdrawl amount {amt} is successful'
try:
    print(withdrawl(2000,2000)) 
except insufficient_funds as e:
    print(e)
# Out:
# acc-1031 withdrawl amount 2000.0 is successful

# %% [markdown]
# ### Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class invalidtransaction(Exception):pass
def transaction(amount,balance,ref='acc-1032'):
    try:
        try:
            amt=float(amount)
            bal=float(balance)
        except(ValueError,TypeError):
            raise invalidtransaction(f'{ref} transaction failed due to invalid input ')
        
        if amt>bal:
            raise invalidtransaction(f'{ref} transaction failed due to insufficient balance')
        else:
            return f'{ref} transaction success amount={amt}'
    except invalidtransaction as e:
        return e
print(transaction('ss',10000))
print(transaction('sds','sda'))
# Out:
# acc-1032 transaction failed due to invalid input
# acc-1032 transaction failed due to invalid input

# %% [markdown]
# ### Q33. Process transfers while isolating bad rows for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transfers = [
    {"to": "ACC-2001", "amount": 500},
    {"to": "ACC-2002", "amount": -20},
    {"to": "ACC-2003", "amount": "bad"},
]
bal=500
for r in transfers:
    try:
        amt=float(r['amount'])
        if amt<=0 or amt> bal:
            raise ValueError(f'fail {amt}')
        bal -=amt
        print(f'acc-1033 ok {r['to']} {amt} balance {bal}')
    except Exception as err:
        print(f'acc-1033 bad{r} {err}')
# Out:
# acc-1033 ok ACC-2001 500.0 balance 0.0
# acc-1033 bad{'to': 'ACC-2002', 'amount': -20} fail -20.0
# acc-1033 bad{'to': 'ACC-2003', 'amount': 'bad'} could not convert string to float: 'bad'

# %% [markdown]
# ### Q34. Retry a transient payment gateway for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def gateway(ref,amount):
    gateway.counter=0
    gateway.counter+=1
    if gateway.counter<3:
        raise ConnectionError('timeout')
    return True

ref='acc-1034'
bal=1000
amt=200
for i in range(1,4):
    try:
        gateway(ref,amt)
        bal-=amt
        print(f'{ref} ok try {i} balance{bal}')
        break
    except ConnectionError as e:
        print(f'{ref} retry {i} {e}')
        if i==3:
            print(f"{ref} fail {e}")
# Out:
# acc-1034 retry 1 timeout
# acc-1034 retry 2 timeout
# acc-1034 retry 3 timeout
# acc-1034 fail timeout

# %% [markdown]
# ### Q35. Log failed standing instructions for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
log=[]
def standing_instructions(ref,amount,balance):
    try:
        if not isinstance(amount,int):
            raise TypeError('type bad')
        if amount<=0 or amount>balance:
            raise ValueError('amt bad')
    except (ValueError,TypeError) as e:
        log.append(f'{ref} business {e}')
    except ConnectionError as e:
        log.append(f'{ref} Infra {e}')
standing_instructions('acc-1035', 200, 1000)
standing_instructions('acc-1035', -200, 1000)
print(standing_instructions('acc-1035', 'abc', 1000))
print(log)
# Out:
# None
# ['acc-1035 business amt bad', 'acc-1035 business type bad']

# %% [markdown]
# ### Q36. Return a structured failure result for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def deposit (amount,ref='acc-1036'):
    try:
        amt=float(amount)
        if amt<=0:
            raise ValueError('deposit amount must be positive')
        return {'succees':True, 'amount':amt}
    except ValueError as e:
        return {'success':False,'error':str(e)}
print(deposit(200))
print(deposit(-200))
# Out:
# {'succees': True, 'amount': 200.0}
# {'success': False, 'error': 'deposit amount must be positive'}

# %% [markdown]
# ### Q37. Validate a nested beneficiary record for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
beneficiary = {
    "name": "john",
    "bank": {"ifsc": "IdFC0301"}
}
try:
    name=beneficiary['name']
    ifsc=beneficiary['bank']['ifsc']
    phone=beneficiary['phone']
    print('beneficiary is valid')
except KeyError as e:
    print('missing',e)
# Out:
# missing 'phone'

# %% [markdown]
# ### Q38. Use a context manager for an audit file for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference='acc-1038'

try:
    with open("audit.txt",'a') as file:
        file.write(f'audit record for {reference}\n')
        print(f'audit file updated successfully')
except OSError as e:
    print('Audit file error:',e)
# Out:
# audit file updated successfully

# %% [markdown]
# ### Q39. Separate validation and recovery for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference= 'acc-1039'
balance=50000
withdraw=6000

try:
    if withdraw<=0:
        raise ValueError('Invalid withdrawl amount')

    if withdraw > balance :
        raise ValueError("Insufficient balance")

    balance=balance - withdraw
    print("transaction successsful",balance)

except ValueError as e:
    print("Transaction Failed")
    print("Balance remains",balance)
# Out:
# transaction successsful 44000

# %% [markdown]
# ### Q40. Collect all kyc validation errors for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference ="acc-1040"

kyc={'name':'',
     'age':16,
     'pan':""
     }

errors=[]

try:
    if not kyc['name']:
        errors.append('Name is missing')

    if kyc ['age'] < 18:
        errors.append('age must be greater than 18')

    if not kyc['pan']:
        errors.append('pan is missing')

    if errors:
        raise ValueError('kyc validation failed')
    print('kyc is valid')

except ValueError as e:
    print(e)
    print('reference:',reference)
    print('Errors')
    for error in errors:
        print('-',error)
# Out:
# kyc validation failed
# reference: acc-1040
# Errors
# - Name is missing
# - age must be greater than 18
# - pan is missing

# %% [markdown]
# ### Q41. Create insufficientfundserror for banking case 2; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class insufficentfundserror(Exception):pass
def withdrawl(amount,balance,ref='acc-1041'):
    amt=float(amount)
    bal=float(balance)
    if amt>bal:
        return insufficentfundserror(f'{ref} amount should be greater than balance')
    else:
        return f'{ref} withdrawl amount is successfully'
try:
    print(withdrawl(20000,2000))
except insufficentfundserror as e:
    print(e)
# Out:
# acc-1041 amount should be greater than balance

# %% [markdown]
# ### Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class invalidtransaction(Exception):pass
def transaction(amount,balance,ref='acc-1042'):
    try:
        try:
            amt=float(amount)
            bal=float(balance)
        except(ValueError,TypeError):
            raise invalidtransaction(f'{ref} transaction failed due to invalid input')
        if amt>bal:
            raise invalidtransaction(f'{ref} transaction failed due to insufficient balance')
        else:
            return f'{ref} transaction success={ref}'
    except invalidtransaction as e:
        return e
print(transaction(100,1000))
print(transaction(803909,3322))
# Out:
# acc-1042 transaction success=acc-1042
# acc-1042 transaction failed due to insufficient balance

# %% [markdown]
# ### Q43. Process transfers while isolating bad rows for banking case 2; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transfers = [
    {"to": "ACC-2001", "amount": 500},
    {"to": "ACC-2002", "amount": -20},
    {"to": "ACC-2003", "amount": "bad"},
]
bal=500
for r in transfers:
    try:
        amt=float(r['amount'])
        if amt<=0 or amt> bal:
            raise ValueError(f'fail {amt}')
        bal -=amt
        print(f'acc-1043 ok {r['to']} {amt} balance {bal}')
    except Exception as err:
        print(f'acc-1433 bad{r} {err}')
# Out:
# acc-1043 ok ACC-2001 500.0 balance 0.0
# acc-1433 bad{'to': 'ACC-2002', 'amount': -20} fail -20.0
# acc-1433 bad{'to': 'ACC-2003', 'amount': 'bad'} could not convert string to float: 'bad'

# %% [markdown]
# ### Q44. Retry a transient payment gateway for banking case 2; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def gateway(ref,amount):
    gateway.counter=0
    gateway.counter+=1
    if gateway.counter<3:
        raise ConnectionError ('timeout')
    return True
ref='acc-1044'
bal=1000
amt=500
for i in range(1,4):
    try:
        gateway(ref,amt)
        bal-=amt
        print(f'{ref} ok try {i} balance {bal}')
        break
    except ConnectionError as e:
        print(f'{ref} retry {i} {e}')
        if i==3:
            print(f'{ref} fail {e}')
# Out:
# acc-1044 retry 1 timeout
# acc-1044 retry 2 timeout
# acc-1044 retry 3 timeout
# acc-1044 fail timeout

# %% [markdown]
# ### Q45. Log failed standing instructions for banking case 2; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
log=[]
def standing_instructions(ref,amount,balance):
    try:
        if not isinstance(amount,int):
            raise TypeError('type bad')
        if amount<=0 or amount>balance:
            raise ValueError('amt bad')
    except (ValueError,TypeError) as e:
        log.append(f'{ref} business {e}')
    except ConnectionError as e:
        log.append(f'{ref} Infra {e}')
standing_instructions('acc-1045', 200, 1000)
standing_instructions('acc-1045', -200, 1000)
print(standing_instructions('acc-1045', 'abc', 1000))
print(log)
# Out:
# None
# ['acc-1045 business amt bad', 'acc-1045 business type bad']

# %% [markdown]
# ### Q46. Return a structured failure result for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def deposit (amount,ref='acc-1046'):
    try:
        amt=float(amount)
        if amt<=0:
            raise ValueError('deposit amount must be positive')
        return {'succees':True, 'amount':amt}
    except ValueError as e:
        return {'success':False,'error':str(e)}
print(deposit(200))
print(deposit(-200))
# Out:
# {'succees': True, 'amount': 200.0}
# {'success': False, 'error': 'deposit amount must be positive'}

# %% [markdown]
# ### Q47. Validate a nested beneficiary record for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
beneficiary = {
    "name": "john",
    "bank": {"ifsc": "IdFC0301"}
}
try:
    name=beneficiary['name']
    ifsc=beneficiary['bank']['ifsc']
    phone=beneficiary['phone']
    print('beneficiary is valid')
except KeyError as e:
    print('missing',e)
# Out:
# missing 'phone'

# %% [markdown]
# ### Q48. Use a context manager for an audit file for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference='acc-1048'

try:
    with open("audit.txt",'a') as file:
        file.write(f'audit record for {reference}\n')
        print(f'audit file updated successfully')
except OSError as e:
    print('Audit file error:',e)
# Out:
# audit file updated successfully

# %% [markdown]
# ### Q49. Separate validation and recovery for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference= 'acc-1049'
balance=50000
withdraw=6000

try:
    if withdraw<=0:
        raise ValueError('Invalid withdrawl amount')

    if withdraw > balance :
        raise ValueError("Insufficient balance")

    balance=balance - withdraw
    print("transaction successsful",balance)

except ValueError as e:
    print("Transaction Failed")
    print("Balance remains",balance)
# Out:
# transaction successsful 44000

# %% [markdown]
# ### Q50. Collect all kyc validation errors for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference ="acc-1050"

kyc={'name':'',
     'age':16,
     'pan':""
     }

errors=[]

try:
    if not kyc['name']:
        errors.append('Name is missing')

    if kyc ['age'] < 18:
        errors.append('age must be greater than 18')

    if not kyc['pan']:
        errors.append('pan is missing')

    if errors:
        raise ValueError('kyc validation failed')
    print('kyc is valid')

except ValueError as e:
    print(e)
    print('reference:',reference)
    print('Errors')
    for error in errors:
        print('-',error)
# Out:
# kyc validation failed
# reference: acc-1050
# Errors
# - Name is missing
# - age must be greater than 18
# - pan is missing

# %% [markdown]
# ### Q51. Create insufficientfundserror for banking case 3; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class insufficentfundserror(Exception):pass
def withdrawl(amount,balance,ref='acc-1051'):
    amt=float(amount)
    bal=float(balance)
    if amt>bal:
        return insufficentfundserror(f'{ref} amount should be greater than balance')
    else:
        return f'{ref} withdrawl amount is successfully'
try:
    print(withdrawl(20000,2000))
except insufficentfundserror as e:
    print(e)
# Out:
# acc-1051 amount should be greater than balance

# %% [markdown]
# ### Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class invalidtransaction(Exception):pass
def transaction(amount,balance,ref='acc-1052'):
    try:
        try:
            amt=float(amount)
            bal=float(balance)
        except(ValueError,TypeError):
            raise invalidtransaction(f'{ref} transaction failed due to invalid input')
        if amt>bal:
            raise invalidtransaction(f'{ref} transaction failed due to insufficient balance')
        else:
            return f'{ref} transaction success={ref}'
    except invalidtransaction as e:
        return e
print(transaction(100,1000))
print(transaction(803909,3322))
# Out:
# acc-1052 transaction success=acc-1052
# acc-1052 transaction failed due to insufficient balance

# %% [markdown]
# ### Q53. Process transfers while isolating bad rows for banking case 3; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transfers = [
    {"to": "ACC-2001", "amount": 500},
    {"to": "ACC-2002", "amount": -20},
    {"to": "ACC-2003", "amount": "bad"},
]
bal=500
for r in transfers:
    try:
        amt=float(r['amount'])
        if amt<=0 or amt> bal:
            raise ValueError(f'fail {amt}')
        bal -=amt
        print(f'acc-1053 ok {r['to']} {amt} balance {bal}')
    except Exception as err:
        print(f'acc-1453 bad{r} {err}')
# Out:
# acc-1053 ok ACC-2001 500.0 balance 0.0
# acc-1453 bad{'to': 'ACC-2002', 'amount': -20} fail -20.0
# acc-1453 bad{'to': 'ACC-2003', 'amount': 'bad'} could not convert string to float: 'bad'

# %% [markdown]
# ### Q54. Retry a transient payment gateway for banking case 3; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def gateway(ref,amount):
    gateway.counter=0
    gateway.counter+=1
    if gateway.counter<3:
        raise ConnectionError ('timeout')
    return True
ref='acc-1054'
bal=1000
amt=500
for i in range(1,4):
    try:
        gateway(ref,amt)
        bal-=amt
        print(f'{ref} ok try {i} balance {bal}')
        break
    except ConnectionError as e:
        print(f'{ref} retry {i} {e}')
        if i==3:
            print(f'{ref} fail {e}')
# Out:
# acc-1054 retry 1 timeout
# acc-1054 retry 2 timeout
# acc-1054 retry 3 timeout
# acc-1054 fail timeout

# %% [markdown]
# ### Q55. Log failed standing instructions for banking case 3; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
log=[]
def standing_instructions(ref,amount,balance):
    try:
        if not isinstance(amount,int):
            raise TypeError('type bad')
        if amount<=0 or amount>balance:
            raise ValueError('amt bad')
    except (ValueError,TypeError) as e:
        log.append(f'{ref} business {e}')
    except ConnectionError as e:
        log.append(f'{ref} Infra {e}')
standing_instructions('acc-1055', 200, 1000)
standing_instructions('acc-1055', -200, 1000)
print(standing_instructions('acc-1055', 'abc', 1000))
print(log)
# Out:
# None
# ['acc-1055 business amt bad', 'acc-1055 business type bad']

# %% [markdown]
# ### Q56. Return a structured failure result for banking case 3; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def deposit (amount,ref='acc-1056'):
    try:
        amt=float(amount)
        if amt<=0:
            raise ValueError('deposit amount must be positive')
        return {'succees':True, 'amount':amt}
    except ValueError as e:
        return {'success':False,'error':str(e)}
print(deposit(200))
print(deposit(-200))
# Out:
# {'succees': True, 'amount': 200.0}
# {'success': False, 'error': 'deposit amount must be positive'}

# %% [markdown]
# ### Q57. Validate a nested beneficiary record for banking case 3; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
beneficiary = {
    "name": "john",
    "bank": {"ifsc": "IdFC0301"}
}
try:
    name=beneficiary['name']
    ifsc=beneficiary['bank']['ifsc']
    phone=beneficiary['phone']
    print('beneficiary is valid')
except KeyError as e:
    print('missing',e)
# Out:
# missing 'phone'

# %% [markdown]
# ### Q58. Use a context manager for an audit file for banking case 3; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference='acc-1058'

try:
    with open("audit.txt",'a') as file:
        file.write(f'audit record for {reference}\n')
        print(f'audit file updated successfully')
except OSError as e:
    print('Audit file error:',e)
# Out:
# audit file updated successfully

# %% [markdown]
# ### Q59. Separate validation and recovery for banking case 3; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference= 'acc-1059'
balance=50000
withdraw=6000

try:
    if withdraw<=0:
        raise ValueError('Invalid withdrawl amount')

    if withdraw > balance :
        raise ValueError("Insufficient balance")

    balance=balance - withdraw
    print("transaction successsful",balance)

except ValueError as e:
    print("Transaction Failed")
    print("Balance remains",balance)
# Out:
# transaction successsful 44000

# %% [markdown]
# ### Q60. Collect all kyc validation errors for banking case 3; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference ="acc-1060"

kyc={'name':'',
     'age':16,
     'pan':""
     }

errors=[]



try:
    if not kyc['name']:
        errors.append('Name is missing')

    if kyc ['age'] < 18:
        errors.append('age must be greater than 18')

    if not kyc['pan']:
        errors.append('pan is missing')

    if errors:
        raise ValueError('kyc validation failed')
    print('kyc is valid')

except ValueError as e:
    print(e)
    print('reference:',reference)
    print('Errors')
    for error in errors:
        print('-',error)
# Out:
# kyc validation failed
# reference: acc-1060
# Errors
# - Name is missing
# - age must be greater than 18
# - pan is missing

# %% [markdown]
# ### Q61. Create insufficientfundserror for banking case 4; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class insufficentfundserror(Exception):pass
def withdrawl(amount,balance,ref='acc-1061'):
    amt=float(amount)
    bal=float(balance)
    if amt>bal:
        return insufficentfundserror(f'{ref} amount should be greater than balance')
    else:
        return f'{ref} withdrawl amount is successfully'
try:
    print(withdrawl(20000,2000))
except insufficentfundserror as e:
    print(e)
# Out:
# acc-1061 amount should be greater than balance

# %% [markdown]
# ### Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class invalidtransaction(Exception):pass
def transaction(amount,balance,ref='acc-1062'):
    try:
        try:
            amt=float(amount)
            bal=float(balance)
        except(ValueError,TypeError):
            raise invalidtransaction(f'{ref} transaction failed due to invalid input')
        if amt>bal:
            raise invalidtransaction(f'{ref} transaction failed due to insufficient balance')
        else:
            return f'{ref} transaction success={ref}'
    except invalidtransaction as e:
        return e
print(transaction(100,1000))
print(transaction(803909,3322))
# Out:
# acc-1062 transaction success=acc-1062
# acc-1062 transaction failed due to insufficient balance

# %% [markdown]
# ### Q63. Process transfers while isolating bad rows for banking case 4; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
transfers = [
    {"to": "ACC-2001", "amount": 500},
    {"to": "ACC-2002", "amount": -20},
    {"to": "ACC-2003", "amount": "bad"},
]
bal=500
for r in transfers:
    try:
        amt=float(r['amount'])
        if amt<=0 or amt> bal:
            raise ValueError(f'fail {amt}')
        bal -=amt
        print(f'acc-1063 ok {r['to']} {amt} balance {bal}')
    except Exception as err:
        print(f'acc-1453 bad{r} {err}')
# Out:
# acc-1063 ok ACC-2001 500.0 balance 0.0
# acc-1453 bad{'to': 'ACC-2002', 'amount': -20} fail -20.0
# acc-1453 bad{'to': 'ACC-2003', 'amount': 'bad'} could not convert string to float: 'bad'

# %% [markdown]
# ### Q64. Retry a transient payment gateway for banking case 4; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def gateway(ref,amount):
    gateway.counter=0
    gateway.counter+=1
    if gateway.counter<3:
        raise ConnectionError ('timeout')
    return True
ref='acc-1064'
bal=1000
amt=500
for i in range(1,4):
    try:
        gateway(ref,amt)
        bal-=amt
        print(f'{ref} ok try {i} balance {bal}')
        break
    except ConnectionError as e:
        print(f'{ref} retry {i} {e}')
        if i==3:
            print(f'{ref} fail {e}')
# Out:
# acc-1064 retry 1 timeout
# acc-1064 retry 2 timeout
# acc-1064 retry 3 timeout
# acc-1064 fail timeout

# %% [markdown]
# ### Q65. Log failed standing instructions for banking case 4; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
log=[]
def standing_instructions(ref,amount,balance):
    try:
        if not isinstance(amount,int):
            raise TypeError('type bad')
        if amount<=0 or amount>balance:
            raise ValueError('amt bad')
    except (ValueError,TypeError) as e:
        log.append(f'{ref} business {e}')
    except ConnectionError as e:
        log.append(f'{ref} Infra {e}')
standing_instructions('acc-1065', 200, 1000)
standing_instructions('acc-1065', -200, 1000)
print(standing_instructions('acc-1065', 'abc', 1000))
print(log)
# Out:
# None
# ['acc-1065 business amt bad', 'acc-1065 business type bad']

# %% [markdown]
# ### Q66. Return a structured failure result for banking case 4; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def deposit (amount,ref='acc-1066'):
    try:
        amt=float(amount)
        if amt<=0:
            raise ValueError('deposit amount must be positive')
        return {'succees':True, 'amount':amt}
    except ValueError as e:
        return {'success':False,'error':str(e)}
print(deposit(200))
print(deposit(-200))
# Out:
# {'succees': True, 'amount': 200.0}
# {'success': False, 'error': 'deposit amount must be positive'}

# %% [markdown]
# ### Q67. Validate a nested beneficiary record for banking case 4; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
beneficiary = {
    "name": "john",
    "bank": {"ifsc": "IdFC0301"}
}
try:
    name=beneficiary['name']
    ifsc=beneficiary['bank']['ifsc']
    phone=beneficiary['phone']
    print('beneficiary is valid')
except KeyError as e:
    print('missing',e)
# Out:
# missing 'phone'

# %% [markdown]
# ### Q68. Use a context manager for an audit file for banking case 4; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference='acc-1068'

try:
    with open("audit.txt",'a') as file:
        file.write(f'audit record for {reference}\n')
        print(f'audit file updated successfully')
except OSError as e:
    print('Audit file error:',e)
# Out:
# audit file updated successfully

# %% [markdown]
# ### Q69. Separate validation and recovery for banking case 4; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference= 'acc-1069'
balance=50000
withdraw=6000

try:
    if withdraw<=0:
        raise ValueError('Invalid withdrawl amount')

    if withdraw > balance :
        raise ValueError("Insufficient balance")

    balance=balance - withdraw
    print("transaction successsful",balance)

except ValueError as e:
    print("Transaction Failed")
    print("Balance remains",balance)
# Out:
# transaction successsful 44000

# %% [markdown]
# ### Q70. Collect all kyc validation errors for banking case 4; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
reference ="acc-1070"

kyc={'name':'',
     'age':16,
     'pan':""
     }

errors=[]



try:
    if not kyc['name']:
        errors.append('Name is missing')

    if kyc ['age'] < 18:
        errors.append('age must be greater than 18')

    if not kyc['pan']:
        errors.append('pan is missing')

    if errors:
        raise ValueError('kyc validation failed')
    print('kyc is valid')

except ValueError as e:
    print(e)
    print('reference:',reference)
    print('Errors')
    for error in errors:
        print('-',error)

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a banking exception hierarchy for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):pass

class accountnotfoundError(BankingError):pass

class insufficientbalanceError(BankingError):pass

class invalidTransactionError(BankingError):pass

class invalidamountError(BankingError):pass

def withdraw(account_no,balance,amount):
    try:
        
        if not isinstance(amount,(int,float)):
            raise invalidamountError('amount must be a number')

        if amount <=0:
            raise invalidamountError('amount must be greater than 0')

        if balance < amount:
            raise insufficientbalanceError(
                f'Insufficient Balance in account{account_no}'

            )
        balance-=amount
        return balance
    except BankingError:
        raise
account_no='acc-1071'
balance=10000

try:
    balance=withdraw(account_no,balance,12000)
    print('withdraw sucessful')
    print('new_blanace',balance)
except insufficientbalanceError as e:
    print('banking error',e)
except invalidamountError as e:
    print('invalid amount',e)
except BankingError as e:
    print('Banking Error',e)
# Out:
# banking error Insufficient Balance in accountacc-1071

# %% [markdown]
# ### Q72. Make a transfer rollback-safe for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transfer(balance1,balance2,amount):
    old1,old2=balance1,balance2

    try:
        if amount > balance :
            raise Exception('insufficient balance')

        balance1-=amount
        balance2-=amount
        print('transfer succcessful')

    except Exception as e:
        balance1,balance2 = old1,old2
        print('Transfer failed',e)
        print('rollback completed')
    return balance1,balance2

a,b=transfer(10000,5000,3000)

print('acc-1072',a)
print('acc-2',b)
# Out:
# transfer succcessful
# acc-1072 7000
# acc-2 2000

# %% [markdown]
# ### Q73. Preserve causes across service layers for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankError(Exception):pass

def service():
    try:
        raise ValueError('invalid account')
    except ValueError as e:
        raise BankError('banking service failed') from e
try:
    service()
except BankError as e:
    print("Error",e)
    print("cause",e.__cause__)
# Out:
# Error banking service failed
# cause invalid account

# %% [markdown]
# ### Q74. Implement bounded exponential retry for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import time

def bank_operation():
    print("trying transaction")
    raise ConnectionError('server busy')
for i in range(3):
    try:
        bank_operation()
        break
    except ConnectionError as e:
        print('retry',i+1)
        time.sleep(2**i)
# Out:
# trying transaction
# retry 1
# trying transaction
# retry 2
# trying transaction
# retry 3

# %% [markdown]
# ### Q75. Create a transaction context manager for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transaction:
    def __enter__(self):
        print("Transaction started")
    def __exit__(self,error_Type,error,traceback):
        if error_Type:
            print("roll back")
        else:
            print("commit")
with Transaction():
    print('acc-1075 transaction successful')
# Out:
# Transaction started
# acc-1075 transaction successful
# commit

# %% [markdown]
# ### Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from collections import deque

dead_letter_queue=deque()

account= 'acc-1076'
payment=5000

try:
    if payment<=0:
        raise ValueError ("Invalid Payment")

    raise RuntimeError('Payment processing failed')
except ValueError as e:
    print('Business rule failure',e)
except RuntimeError as e:
    dead_letter_queue.append({
        "account":account,
        'payment':payment,
        'error':str(e)
    })
    print('payment moved to dead letter queue')
print('dead letter queue',list(dead_letter_queue))
# Out:
# payment moved to dead letter queue
# dead letter queue [{'account': 'acc-1076', 'payment': 5000, 'error': 'Payment processing failed'}]

# %% [markdown]
# ### Q77. Make batch settlement failure-isolated for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
payments=[
    ("acc-1077",1000),
    ('acc-1078',2000),
    ('acc-2093',-300)
]

successful=[]
failed=[]

for account,amount in payments:
    try:
        if amount <=0:
            raise ValueError('Transaction must be in Positive')
        print(account,"setteled successfully")
        successful.append(account)
    except ValueError as e:
        print(account,"settlement failed")
        failed.append(account)
print('successful',successful)
print('failed',failed)
# Out:
# acc-1077 setteled successfully
# acc-1078 setteled successfully
# acc-2093 settlement failed
# successful ['acc-1077', 'acc-1078']
# failed ['acc-2093']

# %% [markdown]
# ### Q78. Report exact paths in nested statements for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account="acc-1078"
balance=5000
amount=4999

try:
    if amount <=balance:
        try:
            balance=balance-amount
            print("payment successful")
        except TypeError:
            print("Invalid Amount type")
    else:
        print('insufficient balance')
except Exception as e:
    print("Error",e)
print("Final Balance",balance)
# Out:
# payment successful
# Final Balance 1

# %% [markdown]
# ### Q79. Design idempotent recovery after timeout for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account="acc-1079"
amount=2000

try:
    print("processing payment")

    print('payment processed')

    raise TimeoutError("request timed out")
except TimeoutError as e:
    print("Timeout Occured")

    print("checking previous transactions")
    print("Transaction already processed - no duplicate payments")

print("recovery completed for",account)
# Out:
# processing payment
# payment processed
# Timeout Occured
# checking previous transactions
# Transaction already processed - no duplicate payments
# recovery completed for acc-1079

# %% [markdown]
# ### Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account='acc-1080'
expected=5000
actual=5000

try:
    print('starting reconciliation')

    if expected != actual:
        raise ValueError("Balance Mismatch")
    print("reconciliation successful")

except ValueError as e:
    print("reconciliation failed",e)

except Exception as e:
    print("Unexcepted error",e)
print('process completed for',account)
# Out:
# starting reconciliation
# reconciliation successful
# process completed for acc-1080

# %% [markdown]
# ### Q81. Design a banking exception hierarchy for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):pass

class accountnotfoundError(BankingError):pass

class insufficientbalanceError(BankingError):pass

class invalidTransactionError(BankingError):pass

class invalidamountError(BankingError):pass

def withdraw(account_no,balance,amount):
    try:
        
        if not isinstance(amount,(int,float)):
            raise invalidamountError('amount must be a number')

        if amount <=0:
            raise invalidamountError('amount must be greater than 0')

        if balance < amount:
            raise insufficientbalanceError(
                f'Insufficient Balance in account{account_no}'

            )
        balance-=amount
        return balance
    except BankingError:
        raise
account_no='acc-1871'
balance=10000

try:
    balance=withdraw(account_no,balance,12000)
    print('withdraw sucessful')
    print('new_blanace',balance)
except insufficientbalanceError as e:
    print('banking error',e)
except invalidamountError as e:
    print('invalid amount',e)
except BankingError as e:
    print('Banking Error',e)
# Out:
# banking error Insufficient Balance in accountacc-1871

# %% [markdown]
# ### Q82. Make a transfer rollback-safe for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transfer(balance1,balance2,amount):
    old1,old2=balance1,balance2

    try:
        if amount > balance :
            raise Exception('insufficient balance')

        balance1-=amount
        balance2-=amount
        print('transfer succcessful')

    except Exception as e:
        balance1,balance2 = old1,old2
        print('Transfer failed',e)
        print('rollback completed')
    return balance1,balance2

a,b=transfer(10000,5000,3000)

print('acc-1082',a)
print('acc-2',b)
# Out:
# Transfer failed insufficient balance
# rollback completed
# acc-1082 10000
# acc-2 5000

# %% [markdown]
# ### Q83. Preserve causes across service layers for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankError(Exception):pass

def service():
    try:
        raise ValueError('invalid account')
    except ValueError as e:
        raise BankError('banking service failed') from e
try:
    service()
except BankError as e:
    print("Error",e)
    print("cause",e.__cause__)
# Out:
# Error banking service failed
# cause invalid account

# %% [markdown]
# ### Q84. Implement bounded exponential retry for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import time

def bank_operation():
    print("trying transaction")
    raise ConnectionError('server busy')
for i in range(3):
    try:
        bank_operation()
        break
    except ConnectionError as e:
        print('retry',i+1)
        time.sleep(2**i)
# Out:
# trying transaction
# retry 1
# trying transaction
# retry 2
# trying transaction
# retry 3

# %% [markdown]
# ### Q85. Create a transaction context manager for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class Transaction:
    def __enter__(self):
        print("Transaction started")
    def __exit__(self,error_Type,error,traceback):
        if error_Type:
            print("roll back")
        else:
            print("commit")
with Transaction():
    print('acc-1085 transaction successful')
# Out:
# Transaction started
# acc-1085 transaction successful
# commit

# %% [markdown]
# ### Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from collections import deque

dead_letter_queue=deque()

account= 'acc-1086'
payment=5000

try:
    if payment<=0:
        raise ValueError ("Invalid Payment")

    raise RuntimeError('Payment processing failed')
except ValueError as e:
    print('Business rule failure',e)
except RuntimeError as e:
    dead_letter_queue.append({
        "account":account,
        'payment':payment,
        'error':str(e)
    })
    print('payment moved to dead letter queue')
print('dead letter queue',list(dead_letter_queue))
# Out:
# payment moved to dead letter queue
# dead letter queue [{'account': 'acc-1076', 'payment': 5000, 'error': 'Payment processing failed'}]

# %% [markdown]
# ### Q87. Make batch settlement failure-isolated for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
payments=[
    ("acc-1087",1000),
    ('acc-1088',2000),
    ('acc-2093',-300)
]

successful=[]
failed=[]

for account,amount in payments:
    try:
        if amount <=0:
            raise ValueError('Transaction must be in Positive')
        print(account,"setteled successfully")
        successful.append(account)
    except ValueError as e:
        print(account,"settlement failed")
        failed.append(account)
print('successful',successful)
print('failed',failed)
# Out:
# acc-1077 setteled successfully
# acc-1078 setteled successfully
# acc-2093 settlement failed
# successful ['acc-1077', 'acc-1078']
# failed ['acc-2093']

# %% [markdown]
# ### Q88. Report exact paths in nested statements for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
balance=5000
amount=4999

try:
    if amount <=balance:
        try:
            balance=balance-amount
            print("payment successful")
        except TypeError:
            print("Invalid Amount type")
    else:
        print('insufficient balance')
except Exception as e:
    print("Error",e)
print("Final Balance",balance)
# Out:
# payment successful
# Final Balance 1

# %% [markdown]
# ### Q89. Design idempotent recovery after timeout for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account="acc-1089"
amount=2000

try:
    print("processing payment")

    print('payment processed')

    raise TimeoutError("request timed out")
except TimeoutError as e:
    print("Timeout Occured")

    print("checking previous transactions")
    print("Transaction already processed - no duplicate payments")

print("recovery completed for",account)
# Out:
# processing payment
# payment processed
# Timeout Occured
# checking previous transactions
# Transaction already processed - no duplicate payments
# recovery completed for acc-1089

# %% [markdown]
# ### Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account='acc-1090'
expected=5000
actual=5000

try:
    print('starting reconciliation')

    if expected != actual:
        raise ValueError("Balance Mismatch")
    print("reconciliation successful")

except ValueError as e:
    print("reconciliation failed",e)

except Exception as e:
    print("Unexcepted error",e)
print('process completed for',account)
# Out:
# starting reconciliation
# reconciliation successful
# process completed for acc-1090

# %% [markdown]
# ### Q91. Design a banking exception hierarchy for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankingError(Exception):pass

class accountnotfoundError(BankingError):pass

class insufficientbalanceError(BankingError):pass

class invalidTransactionError(BankingError):pass

class invalidamountError(BankingError):pass

def withdraw(account_no,balance,amount):
    try:
        
        if not isinstance(amount,(int,float)):
            raise invalidamountError('amount must be a number')

        if amount <=0:
            raise invalidamountError('amount must be greater than 0')

        if balance < amount:
            raise insufficientbalanceError(
                f'Insufficient Balance in account{account_no}'

            )
        balance-=amount
        return balance
    except BankingError:
        raise
account_no='acc-1091'
balance=10000

try:
    balance=withdraw(account_no,balance,12000)
    print('withdraw sucessful')
    print('new_blanace',balance)
except insufficientbalanceError as e:
    print('banking error',e)
except invalidamountError as e:
    print('invalid amount',e)
except BankingError as e:
    print('Banking Error',e)
# Out:
# banking error Insufficient Balance in accountacc-1091

# %% [markdown]
# ### Q92. Make a transfer rollback-safe for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
def transfer(balance1,balance2,amount):
    old1,old2=balance1,balance2

    try:
        if amount > balance :
            raise Exception('insufficient balance')

        balance1-=amount
        balance2-=amount
        print('transfer succcessful')

    except Exception as e:
        balance1,balance2 = old1,old2
        print('Transfer failed',e)
        print('rollback completed')
    return balance1,balance2

a,b=transfer(10000,5000,3000)

print('acc-1092',a)
print('acc-2',b)
# Out:
# transfer succcessful
# acc-1092 7000
# acc-2 2000

# %% [markdown]
# ### Q93. Preserve causes across service layers for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
class BankError(Exception):pass

def service():
    try:
        raise ValueError('invalid account')
    except ValueError as e:
        raise BankError('banking service failed') from e
try:
    service()
except BankError as e:
    print("Error",e)
    print("cause",e.__cause__)
# Out:
# Error banking service failed
# cause invalid account

# %% [markdown]
# ### Q94. Implement bounded exponential retry for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
import time

def bank_operation():
    print("trying transaction")
    raise ConnectionError('server busy')
for i in range(3):
    try:
        bank_operation()
        break
    except ConnectionError as e:
        print('retry',i+1)
        time.sleep(2**i)
# Out:
# trying transaction
# retry 1
# trying transaction
# retry 2
# trying transaction
# retry 3

# %% [markdown]
# ### Q95. Create a transaction context manager for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here

class Transaction:
    def __enter__(self):
        print("Transaction started")
    def __exit__(self,error_Type,error,traceback):
        if error_Type:
            print("roll back")
        else:
            print("commit")
with Transaction():
    print('acc-1095 transaction successful')
# Out:
# Transaction started
# acc-1095 transaction successful
# commit

# %% [markdown]
# ### Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
from collections import deque

dead_letter_queue=deque()

account= 'acc-1096'
payment=5000

try:
    if payment<=0:
        raise ValueError ("Invalid Payment")

    raise RuntimeError('Payment processing failed')
except ValueError as e:
    print('Business rule failure',e)
except RuntimeError as e:
    dead_letter_queue.append({
        "account":account,
        'payment':payment,
        'error':str(e)
    })
    print('payment moved to dead letter queue')
print('dead letter queue',list(dead_letter_queue))
# Out:
# payment moved to dead letter queue
# dead letter queue [{'account': 'acc-1096', 'payment': 5000, 'error': 'Payment processing failed'}]

# %% [markdown]
# ### Q97. Make batch settlement failure-isolated for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
payments=[
    ("acc-1097",1000),
    ('acc-1098',2000),
    ('acc-2093',-300)
]

successful=[]
failed=[]

for account,amount in payments:
    try:
        if amount <=0:
            raise ValueError('Transaction must be in Positive')
        print(account,"setteled successfully")
        successful.append(account)
    except ValueError as e:
        print(account,"settlement failed")
        failed.append(account)
print('successful',successful)
print('failed',failed)
# Out:
# acc-1097 setteled successfully
# acc-1098 setteled successfully
# acc-2093 settlement failed
# successful ['acc-1097', 'acc-1098']
# failed ['acc-2093']

# %% [markdown]
# ### Q98. Report exact paths in nested statements for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
balance=5000
amount=4999

try:
    if amount <=balance:
        try:
            balance=balance-amount
            print("payment successful")
        except TypeError:
            print("Invalid Amount type")
    else:
        print('insufficient balance')
except Exception as e:
    print("Error",e)
print("Final Balance",balance)
# Out:
# payment successful
# Final Balance 1

# %% [markdown]
# ### Q99. Design idempotent recovery after timeout for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account="acc-1099"
amount=2000

try:
    print("processing payment")

    print('payment processed')

    raise TimeoutError("request timed out")
except TimeoutError as e:
    print("Timeout Occured")

    print("checking previous transactions")
    print("Transaction already processed - no duplicate payments")

print("recovery completed for",account)
# Out:
# processing payment
# payment processed
# Timeout Occured
# checking previous transactions
# Transaction already processed - no duplicate payments
# recovery completed for acc-1099

# %% [markdown]
# ### Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
# Write your solution here
account='acc-1100'
expected=5000
actual=5000

try:
    print('starting reconciliation')

    if expected != actual:
        raise ValueError("Balance Mismatch")
    print("reconciliation successful")

except ValueError as e:
    print("reconciliation failed",e)

except Exception as e:
    print("Unexcepted error",e)
print('process completed for',account)
# Out:
# starting reconciliation
# reconciliation successful
# process completed for acc-1100
